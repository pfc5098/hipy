# %%
import matplotlib.pyplot as plt

# create a figure and a set of subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

# use the subplots to create some plots
axs[0,0].plot([1,2,3,4], [1,2,3,4])
axs[0,1].plot([1,2,3,4], [1,4,9,16])
axs[1,0].plot([1,2,3,4], [1,8,27,64])
axs[1,1].plot([1,2,3,4], [1,16,81,256])

# show the plot
plt.show()

# %%
from gtts import gTTS

# Define the text that you want to transform to speech
text = "Alexa, set a timer for 20 minutes"

# Create a gTTS instance with the text
tts = gTTS(text)

# Save the audio file
tts.save("hello.mp3")
